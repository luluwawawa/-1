# %% [markdown]
# #第一章：因果关系入门

# %%
import pandas as pd
import numpy as np
from scipy.special import expit
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style

# %%
np.random.seed(123)
n = 100
tuition = np.random.normal(1000, 300, n).round()
tablet = np.random.binomial(1, expit((tuition - tuition.mean()) / tuition.std())).astype(bool)
enem_score = np.random.normal(200 - 50 * tablet + 0.7 * tuition, 200)
enem_score = (enem_score - enem_score.min()) / enem_score.max()
enem_score *= 1000

data = pd.DataFrame(dict(enem_score=enem_score, Tuition=tuition, Tablet=tablet))
print(data)
# Out:
#     enem_score  Tuition  Tablet
# 0   227.622953    674.0   False
# 1   219.079925   1299.0    True
# 2   400.889622   1085.0   False
# 3   122.761509    548.0   False
# 4   315.064276    826.0   False
# 5   687.073437   1495.0   False
# 6   115.442787    272.0    True
# 7   373.175133    871.0   False
# 8   585.333858   1380.0    True
# 9   306.354895    740.0   False
# 10  338.778561    796.0    True
# 11    0.000000    972.0    True
# 12  557.097962   1447.0    True
# 13  336.866698    808.0   False
# 14  303.867860    867.0    True
# 15  350.107202    870.0   False
# 16  764.926109   1662.0    True
# 17  605.610952   1656.0    True
# 18  793.103743   1301.0    True
# 19  563.012025   1116.0   False
# 20  523.604852   1221.0   False
# 21  564.643319   1447.0    True
# 22  302.270321    719.0   False
# 23  439.635298   1353.0    True
# 24  261.167364    624.0   False
# 25  384.216653    809.0   False
# 26  585.569925   1272.0    True
# 27  320.125851    571.0   False
# 28  350.235953    958.0    True
# 29  151.370853    741.0   False
# ..         ...      ...     ...
# 70  549.987619   1141.0    True
# 71  286.360564    751.0    True
# 72  619.382149   1349.0    True
# 73  306.344835    671.0   False
# 74  136.037693    363.0    True
# 75  889.051133   1312.0    True
# 76  379.420210    879.0   False
# 77  365.853130    962.0    True
# 78  310.712289    749.0   False
# 79  157.640927    518.0   False
# 80  679.308799   1377.0    True
# 81  301.278583    793.0   False
# 82  687.658749   1498.0    True
# 83  567.506397   1242.0   False
# 84  538.398088    906.0   False
# 85  344.339667    674.0   False
# 86  192.234939    780.0   False
# 87  117.890782    636.0   False
# 88  834.687000   1626.0    True
# 89  378.506924   1049.0   False
# 90  417.553165   1345.0   False
# 91  190.279205    620.0   False
# 92  576.183123   1054.0    True
# 93  378.807842   1353.0    True
# 94  254.084444    899.0    True
# 95  451.019929   1309.0    True
# 96  113.288467    675.0    True
# 97  116.042782    591.0   False
# 98  266.238616   1114.0    True
# 99  297.431514    886.0    True
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(6,8))
sns.boxplot(y="enem_score", x="Tablet", data=data).set_title('ENEM score by Tablet in Class')
plt.show()

# %%
pd.DataFrame(dict(
    i= [1,2,3,4],
    y0=[500,600,800,700],
    y1=[450,600,600,750],
    t= [0,0,1,1],
    y= [500,600,600,750],
    te=[-50,0,-200,50],
))

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Tuition", y="enem_score", hue="Tablet", data=data, s=70).set_title('ENEM score by Tuition Cost')
plt.show()
